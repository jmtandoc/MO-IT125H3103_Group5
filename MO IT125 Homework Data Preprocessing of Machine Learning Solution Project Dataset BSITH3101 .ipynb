# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Customer Demographics Data Cleaning

# %%
#Loading customer_demogrphics contaminated data

cust_demo = pd.read_csv(r"C:\Users\jhoan\Downloads\customer_demographics_contaminated.csv")

#Showing only first 10 entries
cust_demo.head(10)

# %%
#Removing Duplicates

cust_demo.drop_duplicates(inplace=True)
cust_demo
# Out:
#                                 CustomerID      Age  Gender  \
# 0     9207fa75-5758-48d1-94ad-19c041e0520f     51.0  Female
# 1     5fb09cd8-a473-46f7-80bd-6e49cf509078      NaN  Female
# 2     c139496e-cc89-498a-bd90-1fb4627b6cff     37.0    Male
# 3     50118139-7264-428f-81cc-a25fddc5d6dd     44.0    Male
# 4     7d1f2bbc-8d16-4fbc-9b37-ece3324e8ed4     50.0  Female
# ...                                    ...      ...     ...
# 3165  48313b18-ccdb-4946-b958-1ebfc92dcc2a     59.0    Male
# 3178  bbe76a26-234f-4a70-b71f-fa9b183f6353  Unknown    Male
# 3183  7eb7f7df-9b0a-416a-829e-bcf4d8bd57dc     55.0    Male
# 3186  ce5cf079-859b-43fa-9609-c6bb7e12c6b7     41.0  Female
# 3195  bbf7c36f-3745-4d3a-9e33-f927c2755f65     45.0  Female
#
#                Location IncomeLevel  SignupDate
# 0            Jensenberg         Low  2022-11-17
# 1          Castilloport        High  2020-07-21
# 2     Lake Jennifertown         NaN  2021-01-01
# 3             Port Carl      Medium  2024-06-10
# ...

# %%
#Showing info summary

cust_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3023 entries, 0 to 3195
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerID   3023 non-null   object
#  1   Age          2747 non-null   object
#  2   Gender       3023 non-null   object
#  3   Location     3023 non-null   object
#  4   IncomeLevel  2738 non-null   object
#  5   SignupDate   3023 non-null   object
# dtypes: object(6)
# memory usage: 165.3+ KB

# %%
#Cleaning Age Column - Changing column to  numeric/int value. Getting Median age and replacing null values to median value.

cust_demo['Age'] = pd.to_numeric(cust_demo['Age'], errors='coerce')
median_age = cust_demo['Age'].median()
cust_demo['Age'].fillna(median_age, inplace=True)
cust_demo['Age'] = cust_demo['Age'].astype(int)
cust_demo
# Out:
# C:\Users\jhoan\AppData\Local\Temp\ipykernel_20996\1356773324.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cust_demo['Age'].fillna(median_age, inplace=True)
#                                 CustomerID  Age  Gender           Location  \
# 0     9207fa75-5758-48d1-94ad-19c041e0520f   51  Female         Jensenberg
# 1     5fb09cd8-a473-46f7-80bd-6e49cf509078   45  Female       Castilloport
# 2     c139496e-cc89-498a-bd90-1fb4627b6cff   37    Male  Lake Jennifertown
# ...

# %%
#Replacing negative values with Median Age

cust_demo['Age']= cust_demo['Age'].replace(-1, median_age)
cust_demo
# Out:
#                                 CustomerID   Age  Gender           Location  \
# 0     9207fa75-5758-48d1-94ad-19c041e0520f  51.0  Female         Jensenberg
# 1     5fb09cd8-a473-46f7-80bd-6e49cf509078  45.0  Female       Castilloport
# 2     c139496e-cc89-498a-bd90-1fb4627b6cff  37.0    Male  Lake Jennifertown
# 3     50118139-7264-428f-81cc-a25fddc5d6dd  44.0    Male          Port Carl
# 4     7d1f2bbc-8d16-4fbc-9b37-ece3324e8ed4  50.0  Female          Jessebury
# ...                                    ...   ...     ...                ...
# 3165  48313b18-ccdb-4946-b958-1ebfc92dcc2a  59.0    Male       South Andrea
# 3178  bbe76a26-234f-4a70-b71f-fa9b183f6353  45.0    Male        Gregoryfurt
# 3183  7eb7f7df-9b0a-416a-829e-bcf4d8bd57dc  55.0    Male    New Anthonyland
# 3186  ce5cf079-859b-43fa-9609-c6bb7e12c6b7  41.0  Female        Adrianhaven
# 3195  bbf7c36f-3745-4d3a-9e33-f927c2755f65  45.0  Female         Roberttown
#
#      IncomeLevel  SignupDate
# ...

# %%
#Replacing missing values with Unknown

cust_demo['IncomeLevel'] = cust_demo['IncomeLevel'].fillna('Unknown')
cust_demo['IncomeLevel'].value_counts()
# Out:
# IncomeLevel
# High       946
# Low        923
# Medium     869
# Unknown    285
# Name: count, dtype: int64

# %%
# Replacing Outliers with 95th Percentile
percentile_95 = cust_demo['Age'].quantile(0.95)
cust_demo['Age'] = np.where(cust_demo['Age']>percentile_95, percentile_95, cust_demo['Age'])
cust_demo
# Out:
#                                 CustomerID   Age  Gender           Location  \
# 0     9207fa75-5758-48d1-94ad-19c041e0520f  51.0  Female         Jensenberg
# 1     5fb09cd8-a473-46f7-80bd-6e49cf509078  45.0  Female       Castilloport
# 2     c139496e-cc89-498a-bd90-1fb4627b6cff  37.0    Male  Lake Jennifertown
# 3     50118139-7264-428f-81cc-a25fddc5d6dd  44.0    Male          Port Carl
# 4     7d1f2bbc-8d16-4fbc-9b37-ece3324e8ed4  50.0  Female          Jessebury
# ...                                    ...   ...     ...                ...
# 3165  48313b18-ccdb-4946-b958-1ebfc92dcc2a  59.0    Male       South Andrea
# 3178  bbe76a26-234f-4a70-b71f-fa9b183f6353  45.0    Male        Gregoryfurt
# 3183  7eb7f7df-9b0a-416a-829e-bcf4d8bd57dc  55.0    Male    New Anthonyland
# 3186  ce5cf079-859b-43fa-9609-c6bb7e12c6b7  41.0  Female        Adrianhaven
# 3195  bbf7c36f-3745-4d3a-9e33-f927c2755f65  45.0  Female         Roberttown
#
#      IncomeLevel  SignupDate
# ...

# %%
#Sign-up data to datetime datatype

cust_demo['SignupDate'] = pd.to_datetime(cust_demo['SignupDate'], format='mixed')
cust_demo
# Out:
#                                 CustomerID   Age  Gender           Location  \
# 0     9207fa75-5758-48d1-94ad-19c041e0520f  51.0  Female         Jensenberg
# 1     5fb09cd8-a473-46f7-80bd-6e49cf509078  45.0  Female       Castilloport
# 2     c139496e-cc89-498a-bd90-1fb4627b6cff  37.0    Male  Lake Jennifertown
# 3     50118139-7264-428f-81cc-a25fddc5d6dd  44.0    Male          Port Carl
# 4     7d1f2bbc-8d16-4fbc-9b37-ece3324e8ed4  50.0  Female          Jessebury
# ...                                    ...   ...     ...                ...
# 3165  48313b18-ccdb-4946-b958-1ebfc92dcc2a  59.0    Male       South Andrea
# 3178  bbe76a26-234f-4a70-b71f-fa9b183f6353  45.0    Male        Gregoryfurt
# 3183  7eb7f7df-9b0a-416a-829e-bcf4d8bd57dc  55.0    Male    New Anthonyland
# 3186  ce5cf079-859b-43fa-9609-c6bb7e12c6b7  41.0  Female        Adrianhaven
# 3195  bbf7c36f-3745-4d3a-9e33-f927c2755f65  45.0  Female         Roberttown
#
#      IncomeLevel SignupDate
# ...

# %%
# Cleaned data to CSV

cust_demo.to_csv(r"C:\Users\jhoan\Downloads\Jupyter Output Files\cleaned_cust_demo.csv")

# %% [markdown]
# # Customer_Transactions Data Cleaning

# %%
#Loading Customer Transactions Data and Just showing first 10

cust_trans = pd.read_csv(r"C:\Users\jhoan\Downloads\customer_transactions_contaminated.csv")
cust_trans.head(10)
# Out:
#                              CustomerID                         TransactionID  \
# 0  60567026-f719-4cd6-849e-137e86d8938f  5ff75116-0a50-4d04-80fb-31e5ccbb0769
# 1  4090ba85-b111-4f75-a792-c777965f5255  2c39b9fe-ff57-4d39-9321-9f5cdf187aa1
# 2  9223891b-73ff-4d5c-b8ae-13ece82ee28b  f79588dd-3db9-4ffa-97f8-7de0e64259f1
# 3  9243eebc-938f-480c-8564-16d503d250de  401c0fc9-60df-4455-ad78-67c132f9897d
# 4  6e3e8eb8-bc0f-4ffe-9f74-5d5efec9502f  2034aebc-8280-4254-a667-92bcd1c2be4f
# 5  3eccdcf9-e8ce-4e44-9f62-8bef88e70672  78dfb45e-16e0-4ecc-8f67-f2e210c31c3e
# 6  7fbc5847-a652-4fc8-a7d8-5e85d846e91b  591f1ea2-c97d-44dd-9539-71ac89b94ff3
# 7  958e5c8d-48ca-42dd-bb71-a766a374233a  fb24e098-3ab9-40a2-bcc3-b8ebb23f549a
# 8  39c6e7d2-6c4b-44c0-8961-ddc1ecbdb0c6  833b026a-7c02-4101-832d-62c07569b0f6
# 9  474f9233-0616-431b-b3e9-a6feabe68abb  f8bde21a-7a6b-41f6-ac39-eeb77640fa9b
#
#   TransactionDate  Amount  ProductCategory  PaymentMethod
# ...

# %%
cust_trans.drop_duplicates(inplace=True)
cust_trans
# Out:
#                                 CustomerID  \
# 0     60567026-f719-4cd6-849e-137e86d8938f
# 1     4090ba85-b111-4f75-a792-c777965f5255
# 2     9223891b-73ff-4d5c-b8ae-13ece82ee28b
# 3     9243eebc-938f-480c-8564-16d503d250de
# 4     6e3e8eb8-bc0f-4ffe-9f74-5d5efec9502f
# ...                                    ...
# 3153  086370e7-8884-47d7-89b0-776401a43e1c
# 3157  7c7df909-aa25-48c7-af9d-6ebe714b28b6
# 3164  79fc606a-c02c-4c39-b065-3e88a59b366c
# 3174  6a84f1a7-f636-4300-bd8d-c7f888460829
# 3177  3ea377e6-1156-457e-8b4e-71fa6663e6bf
#
#                              TransactionID TransactionDate  Amount  \
# 0     5ff75116-0a50-4d04-80fb-31e5ccbb0769      2024-05-15  117.64
# 1     2c39b9fe-ff57-4d39-9321-9f5cdf187aa1      2023-04-26  466.14
# 2     f79588dd-3db9-4ffa-97f8-7de0e64259f1      2022-09-23  563.99
# 3     401c0fc9-60df-4455-ad78-67c132f9897d      2024-04-15  254.44
# 4     2034aebc-8280-4254-a667-92bcd1c2be4f      2024-06-03  590.52
# ...

# %%
#Show summary of data
cust_trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3015 entries, 0 to 3177
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       3015 non-null   object
#  1   TransactionID    3015 non-null   object
#  2   TransactionDate  3015 non-null   object
#  3   Amount           2732 non-null   object
#  4   ProductCategory  2733 non-null   object
#  5   PaymentMethod    3015 non-null   object
# dtypes: object(6)
# memory usage: 164.9+ KB

# %%
#Replace Free to 0
cust_trans['Amount'] = cust_trans['Amount'].replace('Free',0)
cust_trans['Amount'] = cust_trans['Amount'].replace('',0)
cust_trans['Amount'] = cust_trans['Amount'].astype(float)
cust_trans
# Out:
#                                 CustomerID  \
# 0     60567026-f719-4cd6-849e-137e86d8938f
# 1     4090ba85-b111-4f75-a792-c777965f5255
# 2     9223891b-73ff-4d5c-b8ae-13ece82ee28b
# 3     9243eebc-938f-480c-8564-16d503d250de
# 4     6e3e8eb8-bc0f-4ffe-9f74-5d5efec9502f
# ...                                    ...
# 3153  086370e7-8884-47d7-89b0-776401a43e1c
# 3157  7c7df909-aa25-48c7-af9d-6ebe714b28b6
# 3164  79fc606a-c02c-4c39-b065-3e88a59b366c
# 3174  6a84f1a7-f636-4300-bd8d-c7f888460829
# 3177  3ea377e6-1156-457e-8b4e-71fa6663e6bf
#
#                              TransactionID TransactionDate  Amount  \
# 0     5ff75116-0a50-4d04-80fb-31e5ccbb0769      2024-05-15  117.64
# 1     2c39b9fe-ff57-4d39-9321-9f5cdf187aa1      2023-04-26  466.14
# 2     f79588dd-3db9-4ffa-97f8-7de0e64259f1      2022-09-23  563.99
# 3     401c0fc9-60df-4455-ad78-67c132f9897d      2024-04-15  254.44
# 4     2034aebc-8280-4254-a667-92bcd1c2be4f      2024-06-03  590.52
# ...

# %%
#Replace -100 with 5th Percentile
percentile_5 = cust_trans['Amount'].quantile(0.05)
cust_trans['Amount'] = cust_trans['Amount'].replace(-100,percentile_5)
cust_trans
# Out:
#                                 CustomerID  \
# 0     60567026-f719-4cd6-849e-137e86d8938f
# 1     4090ba85-b111-4f75-a792-c777965f5255
# 2     9223891b-73ff-4d5c-b8ae-13ece82ee28b
# 3     9243eebc-938f-480c-8564-16d503d250de
# 4     6e3e8eb8-bc0f-4ffe-9f74-5d5efec9502f
# ...                                    ...
# 3153  086370e7-8884-47d7-89b0-776401a43e1c
# 3157  7c7df909-aa25-48c7-af9d-6ebe714b28b6
# 3164  79fc606a-c02c-4c39-b065-3e88a59b366c
# 3174  6a84f1a7-f636-4300-bd8d-c7f888460829
# 3177  3ea377e6-1156-457e-8b4e-71fa6663e6bf
#
#                              TransactionID TransactionDate   Amount  \
# 0     5ff75116-0a50-4d04-80fb-31e5ccbb0769      2024-05-15  117.640
# 1     2c39b9fe-ff57-4d39-9321-9f5cdf187aa1      2023-04-26  466.140
# 2     f79588dd-3db9-4ffa-97f8-7de0e64259f1      2022-09-23  563.990
# 3     401c0fc9-60df-4455-ad78-67c132f9897d      2024-04-15  254.440
# 4     2034aebc-8280-4254-a667-92bcd1c2be4f      2024-06-03  590.520
# ...

# %%
#Replacing missing values with Median
cust_trans['Amount'] =cust_trans['Amount'].fillna(cust_trans['Amount'].median())
amount_median = cust_trans['Amount'].median()
cust_trans['Amount'] =cust_trans['Amount'].fillna(amount_median)
cust_trans
# Out:
#                                 CustomerID  \
# 0     60567026-f719-4cd6-849e-137e86d8938f
# 1     4090ba85-b111-4f75-a792-c777965f5255
# 2     9223891b-73ff-4d5c-b8ae-13ece82ee28b
# 3     9243eebc-938f-480c-8564-16d503d250de
# 4     6e3e8eb8-bc0f-4ffe-9f74-5d5efec9502f
# ...                                    ...
# 3153  086370e7-8884-47d7-89b0-776401a43e1c
# 3157  7c7df909-aa25-48c7-af9d-6ebe714b28b6
# 3164  79fc606a-c02c-4c39-b065-3e88a59b366c
# 3174  6a84f1a7-f636-4300-bd8d-c7f888460829
# 3177  3ea377e6-1156-457e-8b4e-71fa6663e6bf
#
#                              TransactionID TransactionDate   Amount  \
# 0     5ff75116-0a50-4d04-80fb-31e5ccbb0769      2024-05-15  117.640
# 1     2c39b9fe-ff57-4d39-9321-9f5cdf187aa1      2023-04-26  466.140
# 2     f79588dd-3db9-4ffa-97f8-7de0e64259f1      2022-09-23  563.990
# 3     401c0fc9-60df-4455-ad78-67c132f9897d      2024-04-15  254.440
# 4     2034aebc-8280-4254-a667-92bcd1c2be4f      2024-06-03  590.520
# ...

# %%
#Replacing null values with Unknown
cust_trans['ProductCategory'] = cust_trans['ProductCategory'].fillna('Unknown')
cust_trans
# Out:
#                                 CustomerID  \
# 0     60567026-f719-4cd6-849e-137e86d8938f
# 1     4090ba85-b111-4f75-a792-c777965f5255
# 2     9223891b-73ff-4d5c-b8ae-13ece82ee28b
# 3     9243eebc-938f-480c-8564-16d503d250de
# 4     6e3e8eb8-bc0f-4ffe-9f74-5d5efec9502f
# ...                                    ...
# 3153  086370e7-8884-47d7-89b0-776401a43e1c
# 3157  7c7df909-aa25-48c7-af9d-6ebe714b28b6
# 3164  79fc606a-c02c-4c39-b065-3e88a59b366c
# 3174  6a84f1a7-f636-4300-bd8d-c7f888460829
# 3177  3ea377e6-1156-457e-8b4e-71fa6663e6bf
#
#                              TransactionID TransactionDate   Amount  \
# 0     5ff75116-0a50-4d04-80fb-31e5ccbb0769      2024-05-15  117.640
# 1     2c39b9fe-ff57-4d39-9321-9f5cdf187aa1      2023-04-26  466.140
# 2     f79588dd-3db9-4ffa-97f8-7de0e64259f1      2022-09-23  563.990
# 3     401c0fc9-60df-4455-ad78-67c132f9897d      2024-04-15  254.440
# 4     2034aebc-8280-4254-a667-92bcd1c2be4f      2024-06-03  590.520
# ...

# %%
#Convert Datetime to datatype
cust_trans['TransactionDate'] = pd.to_datetime(cust_trans['TransactionDate'], format='mixed')
cust_trans
# Out:
#                                 CustomerID  \
# 0     60567026-f719-4cd6-849e-137e86d8938f
# 1     4090ba85-b111-4f75-a792-c777965f5255
# 2     9223891b-73ff-4d5c-b8ae-13ece82ee28b
# 3     9243eebc-938f-480c-8564-16d503d250de
# 4     6e3e8eb8-bc0f-4ffe-9f74-5d5efec9502f
# ...                                    ...
# 3153  086370e7-8884-47d7-89b0-776401a43e1c
# 3157  7c7df909-aa25-48c7-af9d-6ebe714b28b6
# 3164  79fc606a-c02c-4c39-b065-3e88a59b366c
# 3174  6a84f1a7-f636-4300-bd8d-c7f888460829
# 3177  3ea377e6-1156-457e-8b4e-71fa6663e6bf
#
#                              TransactionID TransactionDate   Amount  \
# 0     5ff75116-0a50-4d04-80fb-31e5ccbb0769      2024-05-15  117.640
# 1     2c39b9fe-ff57-4d39-9321-9f5cdf187aa1      2023-04-26  466.140
# 2     f79588dd-3db9-4ffa-97f8-7de0e64259f1      2022-09-23  563.990
# 3     401c0fc9-60df-4455-ad78-67c132f9897d      2024-04-15  254.440
# 4     2034aebc-8280-4254-a667-92bcd1c2be4f      2024-06-03  590.520
# ...

# %%
#Cleaned Data to CSV

cust_trans.to_csv(r"C:\Users\jhoan\Downloads\Jupyter Output Files\cleaned_cust_trans.csv")

# %% [markdown]
# # Social Media Interactions Data Cleaning

# %%
#Loading Social Media Interactions Dataset

soc_med = pd.read_csv(r"C:\Users\jhoan\Downloads\social_media_interactions_contaminated.csv")
soc_med.head(10)
# Out:
#                              CustomerID                         InteractionID  \
# 0  2dcb9523-356b-40b2-a67b-1f27797de261  e5d15761-d0a7-4329-89e3-79a892c56097
# 1  e12c37b3-7d4d-472f-9fd8-0df2cb3001aa  02f9f376-70ae-4fcd-9070-1db977939948
# 2  08a911a3-65e6-4f5d-a6a1-ae7ddcbe28a2  a83fa04c-f109-4f24-8ce1-2078154f6a1c
# 3  efdfdfc9-5dbb-4478-911a-101a390a0285  28a69c4b-a2e4-4c74-a130-1132d7733fdf
# 4  ca1e90f6-0e5f-492e-ab92-252ff540da18  d9d1c6f8-5e15-4738-b52b-13c2982420cc
# 5  3e44871b-f56c-4576-b1ca-d1dc999e2166  0c409883-8396-48e4-83fb-887329848696
# 6  aa5eea4b-c948-41f4-9285-229a470002aa  4034dadf-6541-40d6-a7f0-16b20a009c04
# 7  7d83304d-2501-4c9f-ba63-a1a14343e51f  bcfc43e7-c5aa-4dbd-9961-0e108784b199
# 8  bd90f5cb-05a7-40f4-acb1-eedf48b58ffa  d2a06664-703d-4bc1-9401-a06f8c43fda5
# 9  63ee220c-19ae-4113-b45c-276b22b068e1  67cdfb0b-3da6-46b8-a1f4-03b2abc81f58
#
#   InteractionDate   Platform InteractionType Sentiment
# 0      2023-07-11        NaN         Comment       NaN
# ...

# %%
#Removing Duplicates

soc_med.drop_duplicates(inplace=True)
soc_med
# Out:
#                                 CustomerID  \
# 0     2dcb9523-356b-40b2-a67b-1f27797de261
# 1     e12c37b3-7d4d-472f-9fd8-0df2cb3001aa
# 2     08a911a3-65e6-4f5d-a6a1-ae7ddcbe28a2
# 3     efdfdfc9-5dbb-4478-911a-101a390a0285
# 4     ca1e90f6-0e5f-492e-ab92-252ff540da18
# ...                                    ...
# 3166  e06f0e16-8e48-483b-b103-9f105b139ca8
# 3170  4d20c2b1-2f8a-4066-902c-bd068c2adccc
# 3173  b7b84b81-c61b-4f23-b3db-b18010484122
# 3175  5659a8c6-0397-4396-b561-52ec1c8a760b
# 3194  5711d1af-71f2-4b99-a965-3ffdc39d32c8
#
#                              InteractionID InteractionDate   Platform  \
# 0     e5d15761-d0a7-4329-89e3-79a892c56097      2023-07-11        NaN
# 1     02f9f376-70ae-4fcd-9070-1db977939948      2023-07-06    Twitter
# 2     a83fa04c-f109-4f24-8ce1-2078154f6a1c      2024-05-24  Instagram
# 3     28a69c4b-a2e4-4c74-a130-1132d7733fdf      2023-11-01  Instagram
# 4     d9d1c6f8-5e15-4738-b52b-13c2982420cc      2023-07-08  Instagram
# ...

# %%
#Showing data summary

soc_med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3020 entries, 0 to 3194
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       3020 non-null   object
#  1   InteractionID    3020 non-null   object
#  2   InteractionDate  3020 non-null   object
#  3   Platform         2729 non-null   object
#  4   InteractionType  3020 non-null   object
#  5   Sentiment        2711 non-null   object
# dtypes: object(6)
# memory usage: 165.2+ KB

# %%
#Replace null values with Other

soc_med['Platform']= soc_med['Platform'].fillna('Other')
soc_med
# Out:
#                                 CustomerID  \
# 0     2dcb9523-356b-40b2-a67b-1f27797de261
# 1     e12c37b3-7d4d-472f-9fd8-0df2cb3001aa
# 2     08a911a3-65e6-4f5d-a6a1-ae7ddcbe28a2
# 3     efdfdfc9-5dbb-4478-911a-101a390a0285
# 4     ca1e90f6-0e5f-492e-ab92-252ff540da18
# ...                                    ...
# 3166  e06f0e16-8e48-483b-b103-9f105b139ca8
# 3170  4d20c2b1-2f8a-4066-902c-bd068c2adccc
# 3173  b7b84b81-c61b-4f23-b3db-b18010484122
# 3175  5659a8c6-0397-4396-b561-52ec1c8a760b
# 3194  5711d1af-71f2-4b99-a965-3ffdc39d32c8
#
#                              InteractionID InteractionDate   Platform  \
# 0     e5d15761-d0a7-4329-89e3-79a892c56097      2023-07-11      Other
# 1     02f9f376-70ae-4fcd-9070-1db977939948      2023-07-06    Twitter
# 2     a83fa04c-f109-4f24-8ce1-2078154f6a1c      2024-05-24  Instagram
# 3     28a69c4b-a2e4-4c74-a130-1132d7733fdf      2023-11-01  Instagram
# 4     d9d1c6f8-5e15-4738-b52b-13c2982420cc      2023-07-08  Instagram
# ...

# %%
#Replace null Sentiment Values with Previous Value

soc_med['Sentiment'] = soc_med['Sentiment'].fillna(method = 'pad')
soc_med
# Out:
# C:\Users\jhoan\AppData\Local\Temp\ipykernel_20996\417170412.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   soc_med['Sentiment'] = soc_med['Sentiment'].fillna(method = 'pad')
#                                 CustomerID  \
# 0     2dcb9523-356b-40b2-a67b-1f27797de261
# 1     e12c37b3-7d4d-472f-9fd8-0df2cb3001aa
# 2     08a911a3-65e6-4f5d-a6a1-ae7ddcbe28a2
# 3     efdfdfc9-5dbb-4478-911a-101a390a0285
# 4     ca1e90f6-0e5f-492e-ab92-252ff540da18
# ...                                    ...
# 3166  e06f0e16-8e48-483b-b103-9f105b139ca8
# 3170  4d20c2b1-2f8a-4066-902c-bd068c2adccc
# 3173  b7b84b81-c61b-4f23-b3db-b18010484122
# 3175  5659a8c6-0397-4396-b561-52ec1c8a760b
# 3194  5711d1af-71f2-4b99-a965-3ffdc39d32c8
#
#                              InteractionID InteractionDate   Platform  \
# 0     e5d15761-d0a7-4329-89e3-79a892c56097      2023-07-11      Other
# ...

# %%
#Convert Interaction Date to Datatype

soc_med['InteractionDate'] = pd.to_datetime(soc_med['InteractionDate'],format='mixed')
soc_med
# Out:
#                                 CustomerID  \
# 0     2dcb9523-356b-40b2-a67b-1f27797de261
# 1     e12c37b3-7d4d-472f-9fd8-0df2cb3001aa
# 2     08a911a3-65e6-4f5d-a6a1-ae7ddcbe28a2
# 3     efdfdfc9-5dbb-4478-911a-101a390a0285
# 4     ca1e90f6-0e5f-492e-ab92-252ff540da18
# ...                                    ...
# 3166  e06f0e16-8e48-483b-b103-9f105b139ca8
# 3170  4d20c2b1-2f8a-4066-902c-bd068c2adccc
# 3173  b7b84b81-c61b-4f23-b3db-b18010484122
# 3175  5659a8c6-0397-4396-b561-52ec1c8a760b
# 3194  5711d1af-71f2-4b99-a965-3ffdc39d32c8
#
#                              InteractionID InteractionDate   Platform  \
# 0     e5d15761-d0a7-4329-89e3-79a892c56097      2023-07-11      Other
# 1     02f9f376-70ae-4fcd-9070-1db977939948      2023-07-06    Twitter
# 2     a83fa04c-f109-4f24-8ce1-2078154f6a1c      2024-05-24  Instagram
# 3     28a69c4b-a2e4-4c74-a130-1132d7733fdf      2023-11-01  Instagram
# 4     d9d1c6f8-5e15-4738-b52b-13c2982420cc      2023-07-08  Instagram
# ...

# %%
#Cleaned Data to CSV

soc_med.to_csv(r"C:\Users\jhoan\Downloads\Jupyter Output Files\cleaned_soc_med.csv")
